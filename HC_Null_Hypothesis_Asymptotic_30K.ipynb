# %%
# !python -m pip install multiple-hypothesis-testing
# Out:
# ...
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
try:
    from google.colab import drive
    drive.mount('/content/gdrive/')
    # import glob; print(glob.glob('/content/gdrive/Othercomputers/My Laptop/projects/RUNI/Thesis/*'))
    import sys
    sys.path.append('/content/gdrive/Othercomputers/My Laptop/projects/RUNI/Thesis')
except:
    pass

# %%
from Higher_Criticism import Higher_Criticism
from Higher_Analysis import asymptotic_analysis

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['font.family'] = 'monospace'

# %%
N_range = [1000, 2000, 3000, 5000, 6000, 7000, 8000, 10000, 20000, 30000]
hc_models = []
#hc_models += [Higher_Criticism(work_mode='hc', global_max=True, gamma=-gamma_power) for gamma_power in np.linspace(0.1,0.9,9)]
#hc_models += [Higher_Criticism(work_mode='unstable', global_max=True, gamma=-gamma_power) for gamma_power in np.linspace(0.1,0.9,9)]
hc_models += [Higher_Criticism(work_mode='hc', global_max=False, gamma=gamma) for gamma in [0.1]]
hc_models += [Higher_Criticism(work_mode='unstable', global_max=False, gamma=gamma) for gamma in [0.1]]
#hc_models += [Higher_Criticism(work_mode='hc', global_max=False, gamma=gamma) for gamma in [0.1]]
#hc_models += [Higher_Criticism(work_mode='unstable', global_max=False, gamma=gamma) for gamma in [0.1]]
monte_carlo = 10000
chunk_size = 100
asymptotic_analysis(N_range=N_range, beta_range=[0.7], r_range=[0.1, 0.2, 0.3], hc_models=hc_models, monte_carlo=monte_carlo, chunk_size=chunk_size)
asymptotic_analysis(N_range=N_range, beta_range=[0.5], r_range=[0.05], hc_models=hc_models, monte_carlo=monte_carlo, chunk_size=chunk_size)
# Out:
# Working on sample size: 1000
# 100%|██████████| 3/3 [00:07<00:00,  2.50s/it]
# Working on sample size: 2000
# 100%|██████████| 3/3 [00:13<00:00,  4.43s/it]
# Working on sample size: 3000
# 100%|██████████| 3/3 [00:19<00:00,  6.55s/it]
# Working on sample size: 5000
# 100%|██████████| 3/3 [00:31<00:00, 10.51s/it]
# Working on sample size: 6000
# 100%|██████████| 3/3 [00:38<00:00, 12.70s/it]
# Working on sample size: 7000
# 100%|██████████| 3/3 [00:44<00:00, 14.86s/it]
# Working on sample size: 8000
# 100%|██████████| 3/3 [00:50<00:00, 16.91s/it]
# Working on sample size: 10000
# 100%|██████████| 3/3 [01:03<00:00, 21.20s/it]
# Working on sample size: 20000
# 100%|██████████| 3/3 [02:08<00:00, 42.90s/it]
# Working on sample size: 30000
# 100%|██████████| 3/3 [03:12<00:00, 64.14s/it]
# Working on sample size: 1000
# ...
# 100%|██████████| 100/100 [00:02<00:00, 48.31it/s]
# Working on sample size: 2000
# ...
# 100%|██████████| 100/100 [00:04<00:00, 23.63it/s]
# Working on sample size: 3000
# ...
