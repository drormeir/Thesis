# %%
# !python -m pip install multiple-hypothesis-testing
# Out:
# Requirement already satisfied: multiple-hypothesis-testing in d:\venv\thesis\lib\site-packages (0.1.7)
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy>=1.6 in d:\venv\thesis\lib\site-packages (from multiple-hypothesis-testing) (1.26.0)
# Requirement already satisfied: matplotlib>=3.6 in d:\venv\thesis\lib\site-packages (from multiple-hypothesis-testing) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\venv\thesis\lib\site-packages (from matplotlib>=3.6->multiple-hypothesis-testing) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in d:\venv\thesis\lib\site-packages (from matplotlib>=3.6->multiple-hypothesis-testing) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\venv\thesis\lib\site-packages (from matplotlib>=3.6->multiple-hypothesis-testing) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\venv\thesis\lib\site-packages (from matplotlib>=3.6->multiple-hypothesis-testing) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in d:\venv\thesis\lib\site-packages (from matplotlib>=3.6->multiple-hypothesis-testing) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in d:\venv\thesis\lib\site-packages (from matplotlib>=3.6->multiple-hypothesis-testing) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\venv\thesis\lib\site-packages (from matplotlib>=3.6->multiple-hypothesis-testing) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\venv\thesis\lib\site-packages (from matplotlib>=3.6->multiple-hypothesis-testing) (2.8.2)
# Requirement already satisfied: six>=1.5 in d:\venv\thesis\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.6->multiple-hypothesis-testing) (1.16.0)

# %%
try:
    from google.colab import drive
    drive.mount('/content/gdrive/')
    # import glob; print(glob.glob('/content/gdrive/Othercomputers/My Laptop/projects/RUNI/Thesis/*'))
    import sys
    sys.path.append('/content/gdrive/Othercomputers/My Laptop/projects/RUNI/Thesis')
except:
    pass

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['font.family'] = 'monospace'

# %%
from Higher_Criticism import Higher_Criticism
from Higher_Analysis import asymptotic_analysis_multi_size

# %%
N_range = [30000, 50000, 100000, 200000, 500000, 1000000]
hc_models = [Higher_Criticism(work_mode='bonferroni'), Higher_Criticism(work_mode='bh')]
hc_models += [Higher_Criticism(work_mode='hc', global_max=True, gamma=-gamma_power) for gamma_power in np.linspace(0.1,0.9,9)]
hc_models += [Higher_Criticism(work_mode='hc', global_max=True, gamma=gamma) for gamma in np.linspace(0.1,0.4,4)]

asymptotic_analysis_multi_size(N_range=N_range, beta_range=[0.7], r_range=[0.5], hc_models=hc_models, monte_carlo=10000)
asymptotic_analysis_multi_size(N_range=N_range, beta_range=[0.5], r_range=[0.05], hc_models=hc_models, monte_carlo=10000)
# Out:
# Working on sample size: 30000
# 100%|██████████| 100/100 [02:27<00:00,  1.47s/it]
# Working on sample size: 50000
# 100%|██████████| 100/100 [03:50<00:00,  2.31s/it]
# Working on sample size: 100000
# 100%|██████████| 100/100 [07:42<00:00,  4.63s/it]
# Working on sample size: 200000
#  44%|████▍     | 44/100 [07:29<09:32, 10.22s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 6
#       3 hc_models += [Higher_Criticism(work_mode='hc', global_max=True, gamma=-gamma_power) for gamma_power in np.linspace(0.1,0.9,9)]
#       4 hc_models += [Higher_Criticism(work_mode='hc', global_max=True, gamma=gamma) for gamma in np.linspace(0.1,0.4,4)]
# ----> 6 asymptotic_analysis_multi_size(N_range=N_range, beta_range=[0.7], r_range=[0.5], hc_models=hc_models, monte_carlo=10000)
#       7 asymptotic_analysis_multi_size(N_range=N_range, beta_range=[0.5], r_range=[0.05], hc_models=hc_models, monte_carlo=10000)
#
# File d:\projects\RUNI\Thesis\Higher_Analysis.py:29, in asymptotic_analysis_multi_size(N_range, beta_range, r_range, hc_models, monte_carlo, chunk_size)
#      26     random_values = Data_Generator_Base.generate_random_values(N=N, seeds=seeds)
#      27     for ind_generator, signal_generator in enumerate(signal_generators):
#      28         signal_values[ind_generator,:, seed0:seed1] =\
# ---> 29             Higher_Criticism.best_objectives_from_random_values(\
#      30                 hc_models=hc_models, data_generator=signal_generator, random_values=random_values)
#      32 for ind_model, hc_model in enumerate(hc_models):
#      33     noise_values = signal_values[0][ind_model]
#
# File d:\projects\RUNI\Thesis\Higher_Criticism.py:84, in Higher_Criticism.best_objectives_from_random_values(hc_models, data_generator, random_values)
#      82 data_generator.generate_from_random_values(random_values=random_values)
#      83 for i, hc_model in enumerate(hc_models):
# ---> 84     hc_model.run_sorted_p(data_generator.p_values)
#      85     ret[i, :] = hc_model.best_objective
#      86 return ret
#
# File d:\projects\RUNI\Thesis\Higher_Criticism.py:135, in Higher_Criticism.run_sorted_p(self, p_values_sorted)
#     133 elif self.work_mode == 'bonferroni':
#     134     self.objectives = 1 - p_values_sorted
# --> 135     self.num_rejected = np.ones(shape=num_p_vectors, dtype=np.int32)
#     136 elif self.work_mode == 'bh':  # Benjamini Hochberg
#     137     self.objectives = - p_values_sorted / np.arange(1,N+1)
#
# File d:\venv\thesis\Lib\site-packages\numpy\core\numeric.py:136, in ones(shape, dtype, order, like)
#     132     multiarray.copyto(res, z, casting='unsafe')
#     133     return res
# --> 136 @set_array_function_like_doc
#     137 @set_module('numpy')
#     138 def ones(shape, dtype=None, order='C', *, like=None):
#     139     """
#     140     Return a new array of given shape and type, filled with ones.
#     141
#    (...)
#     186
#     187     """
#     188     if like is not None:
#
# KeyboardInterrupt:
