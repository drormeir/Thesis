# %% [markdown]
# ### Porting to Google Colab
# The following cell enables this notebook to run from Google Colab as well as from your local machine IDE.<br>
# You can change `root_directory` and/or `this_notebook_google_path` to point to the directory in your Google account, which contains this notebook, together with the `imgs` sub-directory and the rest of the files.<br>

# %%
import sys
import os
try:
    from google.colab import drive as google_drive # type: ignore
except:
    # no Google Colab --> fall back to local machine
    google_drive = None

if google_drive is not None:
    google_drive_directory = os.path.join('/','content','gdrive')
    google_drive.mount(google_drive_directory)
    all_projects_path = os.path.join(google_drive_directory, 'Othercomputers','My Laptop', 'projects')
elif os.name == 'posix': # Ubuntu
    all_projects_path = os.path.join(os.path.expanduser('~'), 'projects')
elif os.name == 'nt': # Windows
    all_projects_path = os.path.join('d:\\', 'projects')
else:
    raise EnvironmentError("Unsupported operating system")
    
project_path = os.path.join(all_projects_path,'RUNI','Thesis')
assert os.path.exists(project_path), f'Project path {project_path} not found!'
# enable import python files from this notebook's path
sys.path.append(project_path)
# enable reading images and data files from this notebook's path
os.chdir(project_path)

datasets_path = os.path.join(project_path, 'datasets')
assert os.path.exists(datasets_path), f'Datasets path {datasets_path} not found!'

output_path = os.path.join(project_path, 'output')
os.makedirs(output_path, exist_ok=True)
assert os.path.exists(output_path), f'Output path {output_path} not found!'
print(f'Current working directory: {os.getcwd()}')
print(f'Datasets path: {datasets_path}')
print(f'Output path: {output_path}')
# Out:
# Current working directory: /home/dror/projects/RUNI/Thesis
# Datasets path: /home/dror/projects/RUNI/Thesis/datasets
# Output path: /home/dror/projects/RUNI/Thesis/output

# %%
from python.hpc import HybridArray
# Out:
# Detecting CUDA version prior to importing numba...
# Checking nvcc --version...
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2025 NVIDIA Corporation
# Built on Fri_Feb_21_20:23:50_PST_2025
# Cuda compilation tools, release 12.8, V12.8.93
# Build cuda_12.8.r12.8/compiler.35583870_0
# Mon Aug 25 19:45:37 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 575.64.03              Driver Version: 575.64.03      CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce GTX 1650        Off |   00000000:01:00.0 Off |                  N/A |
# | N/A   50C    P8              4W /   50W |     591MiB /   4096MiB |     10%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            2012      G   /usr/lib/xorg/Xorg                      215MiB |
# |    0   N/A  N/A            2499      G   /usr/bin/kwalletd5                        1MiB |
# |    0   N/A  N/A            2732      G   /usr/bin/ksmserver                        1MiB |
# |    0   N/A  N/A            2734      G   /usr/bin/kded5                            1MiB |
# |    0   N/A  N/A            2735      G   /usr/bin/kwin_x11                        70MiB |
# |    0   N/A  N/A            2772      G   /usr/bin/plasmashell                     13MiB |
# |    0   N/A  N/A            2800      G   ...it-kde-authentication-agent-1          1MiB |
# |    0   N/A  N/A            3050      G   /usr/bin/kaccess                          1MiB |
# |    0   N/A  N/A            3068      G   ...-gnu/libexec/DiscoverNotifier          1MiB |
# |    0   N/A  N/A            3287      G   ...ibexec/xdg-desktop-portal-kde          1MiB |
# |    0   N/A  N/A           20902      G   /opt/google/chrome/chrome                 1MiB |
# |    0   N/A  N/A           24456      G   /usr/bin/konsole                          1MiB |
# |    0   N/A  N/A           30234    C+G   ...ersion=20250822-130033.396000         36MiB |
# |    0   N/A  N/A           30242      G   ...ess --variations-seed-version        168MiB |
# |    0   N/A  N/A           37112      C   ...or/venv/thesis3.13/bin/python         58MiB |
# +-----------------------------------------------------------------------------------------+
# Found: nvcc version: 12.8   nvidia-smi cuda version: 12.9
# Numba version: 0.61.2
# import numba.cuda --> SUCCESS!
# numba.njit is available.
# Test numba.cuda drivers...
# CUDA is available and will be used for GPU operations.
# Printing CUDA active device attributes:
# ==================================================
#     Name:                               NVIDIA GeForce GTX 1650
#     Free Memory:                        3139968 [KB]
#     Total Memory:                       3804864 [KB]
#     Compute capability:                 7.5
#     Clock rate:                         1560.00 [MHz]
#     Memory clock rate:                  4001.00 [MHz]
#     Memory bus width:                   128 bits
#     Memory band width (theoretical)     128.03 [GByte/Sec]
#     Number of multiprocessors:          16
#     Minimal grid size:                  128
#     Maximum grid size:                  (2147483647, 65535, 65535)
#     Maximum block dimensions:           (1024, 1024, 64)
#     Maximum threads per block:          1024
#     Warp size:                          32
#     Maximum shared memory per block:    49152 [bytes]
#     Maximum registers per block:        65536
#     Total constant memory:              65536 [bytes]
#     Asynchronous engine count:          3
#     L2 cache size:                      1048576 [bytes]
#     ECC support enabled:                False

# %%
from python.rare_weak_model.rare_weak_model import test_speed_rare_weak_null_hypothesis

# %%
num_monte = 10000
N = 10000
num_execitions = 5

# %%
print('Precompile...')
test_speed_rare_weak_null_hypothesis(N=100, num_monte=100, num_executions=1, use_gpu=True, use_njit=False)
test_speed_rare_weak_null_hypothesis(N=100, num_monte=100, num_executions=1, use_gpu=False, use_njit=True)
# Out:
# Precompile...
# Test Speed rare_weak_null_hypothesis use_gpu=True use_njit=False:   0%|          | 0/1 [00:00<?, ?step/s]/home/dror/venv/thesis3.13/lib/python3.13/site-packages/numba/cuda/dispatcher.py:536: NumbaPerformanceWarning: Grid size 16 will likely result in GPU under-utilization due to low occupancy.
#   warn(NumbaPerformanceWarning(msg))
# Test Speed rare_weak_null_hypothesis use_gpu=True use_njit=False: 100%|██████████| 1/1 [00:00<00:00,  3.24step/s]
# Test Speed rare_weak_null_hypothesis use_gpu=False use_njit=True: 100%|██████████| 1/1 [00:10<00:00, 10.13s/step]

# %%
for use_gpu, use_njit in [(False,False), (False,True), (True, False)]:
    test_speed_rare_weak_null_hypothesis(N=N, num_monte=num_monte, num_executions=num_execitions,\
                        use_gpu=use_gpu, use_njit=use_njit)
# Out:
# Test Speed rare_weak_null_hypothesis use_gpu=False use_njit=False: 100%|██████████| 5/5 [00:54<00:00, 11.00s/step]
# Test Speed rare_weak_null_hypothesis use_gpu=False use_njit=True: 100%|██████████| 5/5 [00:40<00:00,  8.08s/step]
# Test Speed rare_weak_null_hypothesis use_gpu=True use_njit=False: 100%|██████████| 5/5 [00:03<00:00,  1.61step/s]
