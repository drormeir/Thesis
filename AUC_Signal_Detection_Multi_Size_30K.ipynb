# %%
# !python -m pip install multiple-hypothesis-testing

# %%
try:
    from google.colab import drive
    drive.mount('/content/gdrive/')
    # import glob; print(glob.glob('/content/gdrive/Othercomputers/My Laptop/projects/RUNI/Thesis/*'))
    import sys
    sys.path.append('/content/gdrive/Othercomputers/My Laptop/projects/RUNI/Thesis')
except:
    pass

# %%
from Higher_Criticism import *
from Higher_Analysis import AUC_asymptotic_analysis_multi_size

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['font.family'] = 'monospace'

# %%
N_range = [1000, 2000, 3000, 5000, 6000, 7000, 8000, 10000, 20000, 30000]
hc_models = [Bonferroni(alpha=-1), Benjamini_Hochberg(alpha=-1)]
hc_models += [Higher_Criticism(global_max=True, gamma=-gamma_power) for gamma_power in np.linspace(0.1,0.9,9)]
hc_models += [Higher_Criticism(global_max=True, gamma=gamma) for gamma in np.linspace(0.1,0.4,4)]
monte_carlo = 10000
chunk_size = 100

# %%
AUC_asymptotic_analysis_multi_size(N_range=N_range, beta_range=[0.7], r_range=[0.1, 0.2, 0.3], hc_models=hc_models, monte_carlo=monte_carlo, chunk_size=chunk_size)
AUC_asymptotic_analysis_multi_size(N_range=N_range, beta_range=[0.5], r_range=[0.05], hc_models=hc_models, monte_carlo=monte_carlo, chunk_size=chunk_size)
# Out:
# Working on sample size: 1000
# ...
# 100%|██████████| 45/45 [00:07<00:00,  5.81it/s]
# Working on sample size: 2000
# ...
# 100%|██████████| 45/45 [00:07<00:00,  6.27it/s]
# Working on sample size: 3000
# ...
# 100%|██████████| 45/45 [00:07<00:00,  6.11it/s]
# Working on sample size: 5000
# ...
# 100%|██████████| 45/45 [00:07<00:00,  6.24it/s]
# Working on sample size: 6000
# ...
# 100%|██████████| 45/45 [00:07<00:00,  6.23it/s]
# Working on sample size: 7000
# ...
# 100%|██████████| 45/45 [00:07<00:00,  6.25it/s]
# Working on sample size: 8000
# ...
# 100%|██████████| 45/45 [00:07<00:00,  5.92it/s]
# Working on sample size: 10000
# ...
# 100%|██████████| 45/45 [00:07<00:00,  6.35it/s]
# Working on sample size: 20000
# ...
# 100%|██████████| 45/45 [00:07<00:00,  6.34it/s]
# Working on sample size: 30000
# ...
# 100%|██████████| 45/45 [00:07<00:00,  6.34it/s]
# Working on sample size: 1000
# ...
# 100%|██████████| 15/15 [00:02<00:00,  6.35it/s]
# Working on sample size: 2000
# ...
# 100%|██████████| 15/15 [00:02<00:00,  6.44it/s]
# ...
